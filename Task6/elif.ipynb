# %% [markdown]
# 1) Import neccessary libraries

# %%
import cv2 
import numpy as np

# %%
# %pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (3.9.3)
# Requirement already satisfied: numpy>=1.21.2 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from opencv-python) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./PycharmProjects/pandas/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2) Use cv2 and matplotlib to read and display the 'monkey_image'.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
image=cv2.imread('shocked_monkey.jpg')
plt.imshow(image)
plt.show()

# %% [markdown]
# 3) Correct the color type to RGB using cv2 and show the result

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.title("Image in RGB Format")
plt.show()

# %% [markdown]
# 4) Use slicing to set the RED and GREEN channels of the picture to 0 and use the imshow() to show the isoleted blue channel.

# %%
image = image_rgb.copy()
image[:, :, 0] = 0  
image[:, :, 1] = 0  


plt.imshow(image)
plt.show()

# %% [markdown]
# 5) Open the "shocked_guy" image and display it in the notebook. Make sure to correct for the RGB order. Try to read and correct RGB in same line

# %%
image = cv2.imread("shocked_guy.png")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title("RGB Image")
plt.show()

# %% [markdown]
# 6) Flip the image upside down and display it in the notebook.

# %%
flipped_image = cv2.flip(image_rgb, 0)
plt.imshow(flipped_image)
plt.show()

# %% [markdown]
# 7) Copy the image and draw an empty RED rectangle around the human face on coppied image and display the image in the notebook.

# %%
image_copy = image_rgb.copy()
start_point = (1100, 1000)  
end_point = (400, 0)    
color = (255, 0, 0)    
thickness = 5 
cv2.rectangle(image_copy, start_point, end_point, color, thickness)

plt.imshow(image_copy)
plt.axis('off')
plt.title("Kırmızı Dikdörtgen Eklenmiş Görüntü")
plt.show()

# %% [markdown]
# 8) Open the "shocked_cat" image and display it in the notebook as black and white

# %%
cat_image = cv2.imread("shocked_cat.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(cat_image,cmap='gray')
plt.show()
plt.axis('off')
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# 9)Apply a binary 'gray' threshold onto the image.

# %%
threshold_value, binary_image = cv2.threshold(cat_image, 100 ,130,cv2.THRESH_BINARY)
plt.imshow(binary_image, cmap='gray')
plt.show()

# %% [markdown]
# 10) Create a Horizontal Sobel Filter with a kernel size of 5 to the grayscale version of the giaraffes image and then display the resulting gradient filtered version of the image.

# %%
giraffe_image = cv2.imread("giraffes.jpg", cv2.IMREAD_GRAYSCALE)
sobel_horizontal = cv2.Sobel(giraffe_image, cv2.CV_64F, 1, 0, ksize=5)


plt.imshow(sobel_horizontal, cmap='gray')
plt.show()
